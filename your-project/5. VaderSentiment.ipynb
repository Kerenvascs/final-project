# %% [markdown]
# # VADER ( Valence Aware Dictionary for Sentiment Reasoning)
# Vader is a model used for text sentiment analysis that is sensitive to both polarity (positive/negative) and intensity (strength) of emotion.
# It is available in the NLTK package and can be applied directly to unlabeled text data.
#
# https://towardsdatascience.com/sentimental-analysis-using-vader-a3415fef7664
#
# https://pypi.org/project/vaderSentiment/

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
tweets = pd.read_csv('sentiment.csv')
tweets.head(1)
# Out:
#    tweet_count      city                                               body  \
# 0            0  New York  @UberEats Promo Code never works for 50%. what...
#
#                         date hashtags  \
# 0  2020-07-14 23:57:38+00:00      NaN
#
#                                                 link  geo  \
# 0  https://twitter.com/FashionsWeek/status/128318...  NaN
#
#                                            tokenized  \
# 0  ['@', 'UberEats', 'Promo', 'Code', 'never', 'w...
#
#                                              cleaned predicted
# 0  ['ubereats', 'promo', 'code', 'never', 'work',...  Positive

# %% [markdown]
# ## Define functions to predict sentiments

# %%
sid_obj = SentimentIntensityAnalyzer()

def vader_sentiment_pos(x):
    return sid_obj.polarity_scores(x)['pos']

def vader_sentiment_neg(x):
    return sid_obj.polarity_scores(x)['neg']

def vader_sentiment_neu(x):
    return sid_obj.polarity_scores(x)['neu']

def vader_sentiment_compound(x):
    return sid_obj.polarity_scores(x)['compound']

# %%
tweets['pos'] = tweets['cleaned'].apply(vader_sentiment_pos)

tweets['neg'] = tweets['cleaned'].apply(vader_sentiment_neg)

tweets['neu'] = tweets['cleaned'].apply(vader_sentiment_neu)

tweets['compound'] = tweets['cleaned'].apply(vader_sentiment_compound)
tweets.head()
# Out:
#    tweet_count      city                                               body  \
# 0            0  New York  @UberEats Promo Code never works for 50%. what...
# 1            1  New York  Yea they’re terrible smh. @UberEats @Uber_Support
# 2            2  New York       @UberEats when are you coming to upstate ny?
# 3            3  New York  @diginn why does the dig inn app and @UberEats...
# 4            4  New York  For my brother to have his Uber job back! He h...
#
#                         date hashtags  \
# 0  2020-07-14 23:57:38+00:00      NaN
# 1  2020-07-14 23:36:33+00:00      NaN
# 2  2020-07-14 23:33:33+00:00      NaN
# 3  2020-07-14 23:30:41+00:00      NaN
# 4  2020-07-14 23:04:47+00:00      NaN
#
#                                                 link  geo  \
# 0  https://twitter.com/FashionsWeek/status/128318...  NaN
# 1  https://twitter.com/kensthetic_/status/1283183...  NaN
# 2  https://twitter.com/Thebobover/status/12831828...  NaN
# 3  https://twitter.com/Hot4TaterTots/status/12831...  NaN
# 4  https://twitter.com/Rayofshine69/status/128317...  NaN
#
#                                            tokenized  \
# 0  ['@', 'UberEats', 'Promo', 'Code', 'never', 'w...
# 1  ['Yea', 'they', '’', 're', 'terrible', 'smh', ...
# 2  ['@', 'UberEats', 'when', 'are', 'you', 'comin...
# 3  ['@', 'diginn', 'why', 'does', 'the', 'dig', '...
# 4  ['For', 'my', 'brother', 'to', 'have', 'his', ...
#
#                                              cleaned predicted    pos    neg  \
# 0  ['ubereats', 'promo', 'code', 'never', 'work',...  Positive  0.000  0.000
# 1  ['yea', '’', 'terrible', 'smh', 'ubereats', 'u...  Negative  0.000  0.574
# 2              ['ubereats', 'come', 'upstate', 'ny']  Negative  0.000  0.000
# 3  ['diginn', 'dig', 'inn', 'app', 'ubereats', 'd...  Negative  0.000  0.306
# 4  ['brother', 'uber', 'job', 'back', 'dedicated'...  Negative  0.136  0.322
#
#      neu  compound
# 0  1.000    0.0000
# 1  0.426   -0.6597
# 2  1.000    0.0000
# 3  0.694   -0.6486
# 4  0.542   -0.7375

# %%
# # Analyzing compoud
# tweets.loc[tweets['compound'] > 0,'sentiment'] = 'positive'
# tweets.loc[tweets['compound'] == 0,'sentiment'] = 'neutral'
# tweets.loc[tweets['compound'] < 0,'sentiment'] = 'negative'

# %%
# # Analyzing each score
# tweets.loc[tweets['pos'] > 0.5,'v_sentiment'] = 'positive'
# tweets.loc[tweets['neu'] > 0.5,'v_sentiment'] = 'neutral'
# tweets.loc[tweets['neg'] > 0.5,'v_sentiment'] = 'negative'
# tweets.head()

# %% [markdown]
# ## Only positive and negative
# Using compound scores, All values greater than zeroes will be considered a positive review and all values less than zero would be considered as a negative review.

# %%
tweets['sentiment']  = tweets['compound'].apply(lambda x: 'Positive' if x >=0 else 'Negative')
tweets.head()
# Out:
#    tweet_count      city                                               body  \
# 0            0  New York  @UberEats Promo Code never works for 50%. what...
# 1            1  New York  Yea they’re terrible smh. @UberEats @Uber_Support
# 2            2  New York       @UberEats when are you coming to upstate ny?
# 3            3  New York  @diginn why does the dig inn app and @UberEats...
# 4            4  New York  For my brother to have his Uber job back! He h...
#
#                         date hashtags  \
# 0  2020-07-14 23:57:38+00:00      NaN
# 1  2020-07-14 23:36:33+00:00      NaN
# 2  2020-07-14 23:33:33+00:00      NaN
# 3  2020-07-14 23:30:41+00:00      NaN
# 4  2020-07-14 23:04:47+00:00      NaN
#
#                                                 link  geo  \
# 0  https://twitter.com/FashionsWeek/status/128318...  NaN
# 1  https://twitter.com/kensthetic_/status/1283183...  NaN
# 2  https://twitter.com/Thebobover/status/12831828...  NaN
# 3  https://twitter.com/Hot4TaterTots/status/12831...  NaN
# 4  https://twitter.com/Rayofshine69/status/128317...  NaN
#
#                                            tokenized  \
# 0  ['@', 'UberEats', 'Promo', 'Code', 'never', 'w...
# 1  ['Yea', 'they', '’', 're', 'terrible', 'smh', ...
# 2  ['@', 'UberEats', 'when', 'are', 'you', 'comin...
# 3  ['@', 'diginn', 'why', 'does', 'the', 'dig', '...
# 4  ['For', 'my', 'brother', 'to', 'have', 'his', ...
#
#                                              cleaned predicted    pos    neg  \
# 0  ['ubereats', 'promo', 'code', 'never', 'work',...  Positive  0.000  0.000
# 1  ['yea', '’', 'terrible', 'smh', 'ubereats', 'u...  Negative  0.000  0.574
# 2              ['ubereats', 'come', 'upstate', 'ny']  Negative  0.000  0.000
# 3  ['diginn', 'dig', 'inn', 'app', 'ubereats', 'd...  Negative  0.000  0.306
# 4  ['brother', 'uber', 'job', 'back', 'dedicated'...  Negative  0.136  0.322
#
#      neu  compound sentiment
# 0  1.000    0.0000  Positive
# 1  0.426   -0.6597  Negative
# 2  1.000    0.0000  Positive
# 3  0.694   -0.6486  Negative
# 4  0.542   -0.7375  Negative

# %%
tweets.to_csv('vader-sentiment.csv',index=False)
